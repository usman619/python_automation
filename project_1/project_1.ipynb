# %% [markdown]
# # Table Extraction

# %% [markdown]
# ## Basic Table Extraction

# %%
# %pip install pandas
# %pip install lxml

# %%
import pandas as pd

# %%
bleach = pd.read_html('https://en.wikipedia.org/wiki/List_of_Bleach_episodes')

# %%
print("Number of tables extracted: ",len(bleach))
# Out:
# Number of tables extracted:  42

# %%
bleach[1]
# Out:
#     No.                                              Title  \
# 0     1  "The Day I Became a Shinigami" Transliteration...
# 1     2  "A Shinigami's Work" Transliteration: "Shiniga...
# 2     3  "The Older Brother's Wish, the Younger Sister'...
# 3     4  "Cursed Parakeet" Transliteration: "Noroi no I...
# 4     5  "Beat the Invisible Enemy!" Transliteration: "...
# 5     6  "Fight to the Death! Ichigo vs. Ichigo" Transl...
# 6     7  "Greetings from a Stuffed Lion" Transliteratio...
# 7     8  "June 17, Memories in the Rain" Transliteratio...
# 8     9  "Unbeatable Enemy" Transliteration: "Taosenai ...
# 9    10  "Assault on Trip at Sacred Ground!" Transliter...
# 10   11  "The Legendary Quincy" Transliteration: "Dense...
# 11   12  "A Gentle Right Arm" Transliteration: "Yasashi...
# 12   13  "Flower and Hollow" Transliteration: "Hana to ...
# 13   14  "Back to Back, a Fight to the Death!" Translit...
# 14   15  "Kon's Great Plan" Transliteration: "Kon no Uh...
# ...

# %% [markdown]
# ## Extracting CSV files from Websites and PDF file

# %% [markdown]
# Target Website: [https://www.football-data.co.uk/data.php](https://www.football-data.co.uk/data.php)

# %%
df_premier24= pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
df_premier24
# Out:
#     Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00   Man United          Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30      Ipswich       Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00      Arsenal          Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00      Everton        Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00    Newcastle     Southampton     1     0   H     1
# ..   ..         ...    ...          ...             ...   ...   ...  ..   ...
# 154  E0  15/12/2024  14:00     Brighton  Crystal Palace     1     3   A     0
# 155  E0  15/12/2024  16:30     Man City      Man United     1     2   A     1
# 156  E0  15/12/2024  19:00      Chelsea       Brentford     2     1   H     1
# 157  E0  15/12/2024  19:00  Southampton       Tottenham     0     5   A     0
# 158  E0  16/12/2024  20:00  Bournemouth        West Ham     1     1   D     0
#
# ...

# %%
df_premier24.rename(columns={'FTHG':'home_goals','FTAG':'away_goals'},inplace=True)

# %%
df_premier24.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  home_goals  away_goals FTR  \
# 0  E0  16/08/2024  20:00  Man United       Fulham           1           0   H
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool           0           2   A
# 2  E0  17/08/2024  15:00     Arsenal       Wolves           2           0   H
# 3  E0  17/08/2024  15:00     Everton     Brighton           0           3   A
# 4  E0  17/08/2024  15:00   Newcastle  Southampton           1           0   H
#
#    HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0     0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82
# 1     0     0  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99
# 2     1     0  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99
# 3     0     1  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83
# 4     1     0  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82
#
# ...

# %% [markdown]
# Extracting Table for a PDF file
# Install the following dependencies before install the main package 'camelot-py':
# ```bash
# pip install tk
# pip install ghostscript
# pip install opencv-python
# pip install camelot-py
#
# ```

# %%
import camelot

# %%
tables = camelot.read_pdf('assests/pdfs/foo.pdf',pages= '1')

print(tables)
# Out:
# <TableList n=1>

# %%
tables.export('foo.csv',f='csv',compress=True)
tables[0].to_csv('foo.csv')
